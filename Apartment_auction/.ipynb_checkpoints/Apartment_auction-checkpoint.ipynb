# %% [markdown]
# # Data Loader
#
# - Target : 아파트 낙찰가
#
# - Files
# > - **Auction_Master_train.csv** ; 서울/부산 지역의 낙찰가를 포함하여 경매 물건 아파트의 위치, 감정가, 경매 개시/종결일 등의 기본 정보 (최근 2년)
# > - **Auction_Master_test.csv** ; 경매 낙찰가를 제외하고 train.csv와 동일
# > - **Auction_submission.csv** ; 예측한 낙찰가를 기입하여 제출
# > - **Auction_regist.csv** ; 아파트에 대한 등기 정보
# > - **Auction_result.csv** ; 경매일자, 감정가, 최저매각가격, 경매 결과 데이터.
# > - **Auction_rent.csv** ; 해당 아파트에 임차인이 있는 경우, 전입/점유 여부, 보증금, 월세 등의 데이터.
#
# - Features
# > - Auction_key ; 경매 아파트 고유 키값
# > - Auction_class ; 경매구분
# > > - **강제경매** : 법원에 소송을 제기하여 판결을 얻은 후 집행권원에 따라 경매를 진행
# > > - **임의경매** : 등기부등본 담보권(저당권, 가압류등)으로 경매를 진행
# > - Bid_class ; 입찰구분(일반/개별/일괄)
# > - Claim_price ; 경매 신청인의 청구 금액
# > - Appraisal_company ; 감정사
# > - Appraisal_date ; 감정일자
# > - Auction_count ; 총경매횟수
# > - Auction_miscarriage_count ; 총유찰횟수
# > > - 입찰 결과 낙찰(落札)이 결정되지 아니하고 무효로 돌아가는 일. 응찰 가격이 내정 가격에 미달될 때 주로 일어남.
# > - Total_land_gross_area ; 총토지전체면적(㎡)
# > - Total_land_real_area ; 총토지실면적(㎡)
# > - Total_land_auction_area ; 총토지경매면적(㎡)
# > - Total_building_area ; 총건물면적(㎡)
# > - Total_building_auction_area ; 총건물경매면적(㎡)
# > - Total_appraisal_price ; 총감정가
# > - Minimum_sales_price ; 최저매각가격
# > > - 입찰 시 입찰인이 최저로 제시해야만 하는 금액
# > - First_auction_date ; 최초경매일
# > - Final_acution_date ; 최종경매일
# > - Final_result ; 최종결과
# > - Creditor ; 채권자, 경매 신청인
# > - addr_do ; 주소_시도
# > - addr_si ; 시군구
# > - addr_dong ; 읍면동
# > - addr_li ; 리
# > - addr_san ; 주소_산번지 여부(Y)
# > - addr_bunji1 ; 주소_번지1
# > - addr_bunji2 ; 주소_번지2
# > - addr_etc ; 주소_기타주소
# > - Apartment_usage ; 건물(토지)의 대표 용도
# > - Completion_date ; 준공일
# > - Preserve_regist_date ; 보존등기일, 건물을 신축하고 처음으로 등기
# > - Total_floor ; 총 층수
# > - Current_floor ; 현재 층 수
# > - Specific ; 기타_특이사항
# > - Share_auction_YorN ; 지분경매 여부(Y)
# > > - 하나의 부동산이 전체가 아닌 일부만 경매가 진행 (하나의 부동산의 공유자가 지분으로 소유권을 가지고 있을 때 그중 일부 지분만 경매가 진행)
# > - road_name ; 도로명주소_도로명
# > - road_bunji1 ; 도로명주소_번지1
# > - road_bunji2 ; 도로명주소_번지2
# > - Close_date ; 종국일자
# > - Close_result ; 종국결과, 낙찰과 배당의 차이
# > > - 경매 진행은 ①경매진행(낙찰) ▷ ②낙찰허가결정 ▷ ③대금납부 ▷ ④배당 후 종결 로 이뤄집니다. 낙찰자가 최고가로 입찰(①)해서 낙찰허가(②)를 받으면 대금납부기한 낙찰금을 입금(③)합니다. 법원은 납부된 낙찰금을 가지고 채권자에게 순위에 의한 배당(④)을 해주고 경매는 종결됩니다.
# > - point.y ; 위도
# > - point.x ; 경도
# > - Hammer_price ; 낙찰가

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

Raw_train = pd.read_csv("./data/Auction_Master_train.csv")
Raw_test = pd.read_csv("./data/Auction_Master_test.csv")
submission = pd.read_csv("./data/Auction_submission.csv")
regist = pd.read_csv("./data/Auction_regist.csv")
result = pd.read_csv("./data/Auction_result.csv")
rend = pd.read_csv("./data/Auction_result.csv")

# %%
Raw_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Auction_key                  1933 non-null   int64
#  1   Auction_class                1933 non-null   object
#  2   Bid_class                    1933 non-null   object
#  3   Claim_price                  1933 non-null   int64
#  4   Appraisal_company            1933 non-null   object
#  5   Appraisal_date               1933 non-null   object
#  6   Auction_count                1933 non-null   int64
#  7   Auction_miscarriage_count    1933 non-null   int64
#  8   Total_land_gross_area        1933 non-null   float64
#  9   Total_land_real_area         1933 non-null   float64
#  10  Total_land_auction_area      1933 non-null   float64
#  11  Total_building_area          1933 non-null   float64
#  12  Total_building_auction_area  1933 non-null   float64
#  13  Total_appraisal_price        1933 non-null   int64
#  14  Minimum_sales_price          1933 non-null   int64
#  15  First_auction_date           1933 non-null   object
#  16  Final_auction_date           1933 non-null   object
#  17  Final_result                 1933 non-null   object
#  18  Creditor                     1933 non-null   object
#  19  addr_do                      1933 non-null   object
#  20  addr_si                      1933 non-null   object
#  21  addr_dong                    1933 non-null   object
#  22  addr_li                      23 non-null     object
#  23  addr_san                     1933 non-null   object
#  24  addr_bunji1                  1929 non-null   float64
#  25  addr_bunji2                  889 non-null    float64
#  26  addr_etc                     1933 non-null   object
#  27  Apartment_usage              1933 non-null   object
#  28  Preserve_regist_date         1933 non-null   object
#  29  Total_floor                  1933 non-null   int64
#  30  Current_floor                1933 non-null   int64
#  31  Specific                     64 non-null     object
#  32  Share_auction_YorN           1933 non-null   object
#  33  road_name                    1933 non-null   object
#  34  road_bunji1                  1909 non-null   float64
#  35  road_bunji2                  155 non-null    float64
#  36  Close_date                   1933 non-null   object
#  37  Close_result                 1933 non-null   object
#  38  point.y                      1933 non-null   float64
#  39  point.x                      1933 non-null   float64
#  40  Hammer_price                 1933 non-null   int64
# dtypes: float64(11), int64(9), object(21)
# memory usage: 619.3+ KB

# %%
Raw_train.head()
# Out:
#    Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0         2687            임의        개별   1766037301              정명감정
# 1         2577            임의        일반    152946867               희감정
# 2         2197            임의        개별     11326510              혜림감정
# 3         2642            임의        일반    183581724              신라감정
# 4         1958            강제        일반     45887671              나라감정
#
#         Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0  2017-07-26 00:00:00              2                          1
# 1  2016-09-12 00:00:00              2                          1
# 2  2016-11-22 00:00:00              3                          2
# 3  2016-12-13 00:00:00              2                          1
# 4  2016-03-07 00:00:00              2                          1
#
#    Total_land_gross_area  Total_land_real_area  Total_land_auction_area  \
# 0                12592.0                 37.35                    37.35
# 1                42478.1                 18.76                    18.76
# 2               149683.1                 71.00                    71.00
# 3                24405.0                 32.98                    32.98
# 4                  774.0                 45.18                    45.18
#
#    Total_building_area  Total_building_auction_area  Total_appraisal_price  \
# 0               181.77                       181.77              836000000
# 1               118.38                       118.38             1073000000
# 2                49.94                        49.94              119000000
# 3                84.91                        84.91              288400000
# 4                84.96                        84.96              170000000
#
#    Minimum_sales_price   First_auction_date   Final_auction_date Final_result  \
# 0            668800000  2018-02-13 00:00:00  2018-03-20 00:00:00           낙찰
# 1            858400000  2016-12-29 00:00:00  2017-02-02 00:00:00           낙찰
# 2             76160000  2017-07-28 00:00:00  2017-10-13 00:00:00           낙찰
# 3            230720000  2017-07-20 00:00:00  2017-11-02 00:00:00           낙찰
# 4            136000000  2016-07-06 00:00:00  2016-08-03 00:00:00           낙찰
#
#      Creditor addr_do addr_si addr_dong addr_li addr_san  addr_bunji1  \
# 0  베리타스자산관리대부      부산    해운대구        우동     NaN        N       1398.0
# 1      흥국저축은행      부산    해운대구        우동     NaN        N       1407.0
# 2        국민은행      부산     사상구       모라동     NaN        N        552.0
# 3      고려저축은행      부산      남구       대연동     NaN        N        243.0
# 4     Private      부산     사하구       괴정동     NaN        N        399.0
#
#    addr_bunji2                    addr_etc Apartment_usage  \
# 0          NaN         해운대엑소디움 5층 101-502호            주상복합
# 1          NaN  해운대두산위브더제니스 103동 51층 5103호             아파트
# 2          NaN         백양그린 206동 14층 1403호             아파트
# 3         23.0         대연청구 109동 11층 1102호             아파트
# 4          2.0               동조리젠시 7층 703호             아파트
#
#   Preserve_regist_date  Total_floor  Current_floor Specific  \
# 0  2009-07-14 00:00:00           45              5      NaN
# 1  2011-12-16 00:00:00           70             51      NaN
# 2  1992-07-31 00:00:00           15             14      NaN
# 3  2001-07-13 00:00:00           20             11      NaN
# 4  2001-11-27 00:00:00            7              7      NaN
#
#   Share_auction_YorN   road_name  road_bunji1  road_bunji2  \
# 0                  N      해운대해변로         30.0          NaN
# 1                  N      마린시티2로         33.0          NaN
# 2                  N    모라로110번길         88.0          NaN
# 3                  N  황령대로319번가길        110.0          NaN
# 4                  N         오작로         51.0          NaN
#
#             Close_date Close_result    point.y     point.x  Hammer_price
# 0  2018-06-14 00:00:00           배당  35.162717  129.137048     760000000
# 1  2017-03-30 00:00:00           배당  35.156633  129.145068     971889999
# 2  2017-12-13 00:00:00           배당  35.184601  128.996765      93399999
# 3  2017-12-27 00:00:00           배당  35.154180  129.089081     256899000
# 4  2016-10-04 00:00:00           배당  35.099630  128.998874     158660000

# %%
# "총토지 실면적"과 "총토지경매면적"이 서로 다른 example이 있는 지 확인
diff_real = (Raw_train['Total_land_real_area'] != Raw_train['Total_land_auction_area']).sum()
print("real != auction : ", diff_real, "/", len(Raw_train))

# "총건물면적"과 "총건물경매면적"이 서로 다른 example이 있는 지 확인
diff_building = (Raw_train['Total_building_area'] != Raw_train['Total_building_auction_area']).sum()
print("building != auction : ", diff_building, "/", len(Raw_train))
# Out:
# real != auction :  77 / 1933
# building != auction :  79 / 1933

# %%
# "총토지실면적" 보다 "총토지경매면적"이 더 큰 example이 있는 지 확인
comp_real = Raw_train['Total_land_real_area'] < Raw_train['Total_land_auction_area']
print("real >= auction : ", comp_real.sum(), "/", len(Raw_train))

# "총건물면적" 보다 "총건물경매면적"이 더 큰 example이 있는 지 확인
comp_building = Raw_train['Total_building_area'] < Raw_train['Total_building_auction_area']
print("building >= auction : ", comp_building.sum(), "/", len(Raw_train))
# Out:
# real >= auction :  1 / 1933
# building >= auction :  0 / 1933

# %%
# "총토지실면적" 보다 "총토지경매면적"이 더 큰 example 출력
Raw_train[comp_real]
# Out:
#       Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 1000         1416            임의        개별    657000000              경인감정
#
#            Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 1000  2016-01-26 00:00:00              2                          1
#
#       Total_land_gross_area  Total_land_real_area  Total_land_auction_area  \
# 1000                 2418.0                 43.21                    43.22
#
#       Total_building_area  Total_building_auction_area  Total_appraisal_price  \
# 1000               151.03                       151.03              330000000
#
#       Minimum_sales_price   First_auction_date   Final_auction_date  \
# 1000            264000000  2016-06-13 00:00:00  2016-07-25 00:00:00
#
#      Final_result Creditor addr_do addr_si addr_dong addr_li addr_san  \
# 1000           낙찰     국민은행      서울     중랑구       중화동     NaN        N
#
#       addr_bunji1  addr_bunji2                addr_etc Apartment_usage  \
# 1000        207.0         14.0  ,-27 미영리치타운102 2층 207호            주상복합
#
#      Preserve_regist_date  Total_floor  Current_floor Specific  \
# 1000  2007-12-11 00:00:00           15              2      NaN
#
#      Share_auction_YorN road_name  road_bunji1  road_bunji2  \
# 1000                  N       망우로        223.0          8.0
#
#                Close_date Close_result    point.y     point.x  Hammer_price
# 1000  2016-11-08 00:00:00           배당  37.595017  127.077879     341000000

# %%
# 최종적으로 유찰된 example이 있는지 확인
print(Raw_train['Final_result'].unique())

# Close_result에 어떤 값들이 있는 지 확인
print(Raw_train['Close_result'].unique())
# Out:
# ['낙찰']
# ['배당' '    ']

# %%
# Close_result에 NULL 값이 포함되어 있는 지 확인
print(Raw_train['Close_result'].isnull().sum())
# Out:
# 0

# %%
# '배당' 이 아닌 종국결과를 출력
# 아마 낙찰은 받았지만 어떠한 이유에서 아직 배당을 받지 못한 경우인 듯 함.
# 즉, 낙찰을 되었지만 아직 배당되지 않아서 경매가 진행 중인 상황인 듯 함.
Raw_train[Raw_train['Close_result'] != '배당']
# Out:
#       Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 962            14            임의        일반   1138371040             리파인감정
# 1016            1            강제        개별    900000000              신명감정
# 1026          843            강제        일반    117409245              도시감정
# 1040          264            임의        일반     94459726              지녕감정
# 1146         1215            임의        일반     80000000              현산감정
# 1407         1738            임의        일반     70000000              화신감정
# 1438          627            임의        일반    138000000             온누리감정
# 1627         1202            강제        일반    238616280              성민감정
# 1640         1683            강제        일반     64100475              기린감정
# 1665         1667            임의        일반    181697863             프라임감정
# 1867         1639            임의        일반    300000000              경인감정
# 1924         1750            임의        일반    178831561             에이원감정
#
#            Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 962   2014-04-14 00:00:00              2                          1
# 1016  2016-03-15 00:00:00              5                          4
# 1026  2016-06-10 00:00:00              1                          0
# 1040  2016-11-04 00:00:00              1                          0
# 1146  2017-02-09 00:00:00              2                          1
# 1407  2017-09-25 00:00:00              2                          1
# 1438  2017-06-21 00:00:00              2                          1
# 1627  2016-11-17 00:00:00              2                          1
# 1640  2017-04-28 00:00:00              2                          1
# 1665  2017-03-28 00:00:00              2                          1
# 1867  2017-01-05 00:00:00              1                          0
# 1924  2017-03-08 00:00:00              1                          0
#
#       Total_land_gross_area  Total_land_real_area  Total_land_auction_area  \
# 962                 15487.3                 78.55                    78.55
# 1016                  510.0                 35.11                    23.41
# 1026                30235.4                 47.17                    47.17
# 1040                  259.1                 20.42                    20.42
# 1146                 1145.0                 56.86                    56.86
# 1407                82595.1                 57.37                    57.37
# 1438                 1391.5                 52.23                    52.23
# 1627                  893.0                 47.22                    47.22
# 1640                25472.5                 26.07                    26.07
# 1665                  531.3                 44.27                    44.27
# 1867                85205.0                 52.29                    52.29
# 1924                25064.5                 34.90                    34.90
#
#       Total_building_area  Total_building_auction_area  Total_appraisal_price  \
# 962                168.42                       168.42             1360000000
# 1016                92.03                        61.35              298000000
# 1026                84.99                        84.99              667000000
# 1040                50.10                        50.10              300000000
# 1146                94.62                        94.62              286000000
# 1407               102.70                       102.70              536000000
# 1438                84.74                        84.74              452000000
# 1627               119.92                       119.92              605000000
# 1640                84.32                        84.32              340000000
# 1665                84.38                        84.38              277000000
# 1867                68.86                        68.86              350000000
# 1924                84.50                        84.50              439000000
#
#       Minimum_sales_price   First_auction_date   Final_auction_date  \
# 962            1088000000  2014-12-09 00:00:00  2016-04-05 00:00:00
# 1016            122061000  2011-06-21 00:00:00  2016-10-11 00:00:00
# 1026            667000000  2017-11-07 00:00:00  2017-11-07 00:00:00
# 1040            300000000  2017-09-20 00:00:00  2017-09-20 00:00:00
# 1146            228800000  2017-12-26 00:00:00  2018-02-06 00:00:00
# 1407            428800000  2018-01-22 00:00:00  2018-03-05 00:00:00
# 1438            361600000  2018-01-29 00:00:00  2018-03-05 00:00:00
# 1627            484000000  2017-05-23 00:00:00  2017-06-28 00:00:00
# 1640            272000000  2017-09-11 00:00:00  2017-11-06 00:00:00
# 1665            221600000  2017-08-28 00:00:00  2017-10-16 00:00:00
# 1867            350000000  2017-04-24 00:00:00  2017-12-11 00:00:00
# 1924            439000000  2017-07-03 00:00:00  2017-09-18 00:00:00
#
#      Final_result Creditor addr_do addr_si addr_dong addr_li addr_san  \
# 962            낙찰  안양남부(새)      서울     강남구       개포동     NaN        N
# 1016           낙찰  푸른이상호저축      서울     동작구       상도동     NaN        N
# 1026           낙찰  Private      서울     마포구       창전동     NaN        N
# 1040           낙찰  Private      서울     강남구       논현동     NaN        N
# 1146           낙찰  Private      서울     구로구       온수동     NaN        N
# 1407           낙찰  Private      서울     중랑구        묵동     NaN        N
# 1438           낙찰  Private      서울     강동구       성내동     NaN        N
# 1627           낙찰  Private      서울     양천구       신정동     NaN        N
# 1640           낙찰  Private      서울     중랑구       신내동     NaN        N
# 1665           낙찰  Private      서울     중랑구       망우동     NaN        N
# 1867           낙찰   중소기업은행      서울     노원구       상계동     NaN        N
# 1924           낙찰   굿이에프대부      서울     도봉구        창동     NaN        N
#
#       addr_bunji1  addr_bunji2                          addr_etc  \
# 962          12.0          2.0               엘지개포자이 101동 5층 502호
# 1016          1.0          5.0                      삼부한강 2층 201호
# 1026        444.0          NaN    ,445-4,448 서강쌍용예가 111동 4층 404호
# 1040        102.0          9.0                     논현빌라트 5층 502호
# 1146         97.0          2.0                ,99-4 두양그린 5층 503호
auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 29           1783            강제        개별   1087000000              대한감정
# 32           1826            임의        일반     45000000              태화감정
# 81           1914            강제        일반    180000000             태평양감정
# 84           1781            강제        개별   1087000000              대한감정
# 118          1986            임의        일반     70000000              알비감정
# 122          1780            강제        개별   1087000000              대한감정
# 224          1789            강제        개별   1087000000              대한감정
# 227          2489            강제        일반    264300000              국제감정
# 239          1787            강제        개별   1087000000              대한감정
# 294          2497            강제        일반    264300000             오상호감정
# 303          2533            임의        일반    410382851             한마음감정
# 311          1785            강제        개별   1087000000              대한감정
# 370          1797            강제        개별   1087000000              대한감정
# 464          1791            강제        개별   1087000000              대한감정
# 491          1794            강제        개별   1087000000              대한감정
# 496          1776            강제        개별   1087000000              대한감정
# 519          2301            임의        일반    281292053              대일감정
# 560          1796            강제        개별   1087000000              대한감정
# 613          1782            강제        개별   1087000000              대한감정
# 626          2401            임의        일반    137996981              한라감정
# 637          1788            강제        개별   1087000000              대한감정
# 656          1777            강제        개별   1087000000              대한감정
# 658          1795            강제        개별   1087000000              대한감정
# 731           906            강제        개별     36500000              한울감정
# 777           271            임의        일반    404899792            현대기업감정
# 779          1477            임의        일반    233237278              두환감정
# 823          1608            임의        개별    600000000              이노감정
# 844            43            임의        일반    120000000              두환감정
# 853          1651            임의        일반     43170233              지평감정
# 866          1002            임의        일반    514161871              구정감정
# 917          1068            임의        일반    872504514              한터감정
# 1065          765            강제        일반    400000000              로얄감정
# 1212         1437            임의        일괄    600000000              영현감정
# 1266          953            임의        일반     49895283             엘리트감정
# 1316          445            강제        일반    380000000              준경감정
# 1438          627            임의        일반    138000000             온누리감정
# 1486          854            강제        일반    180000000              원일감정
# 1521           10            강제        일괄   8955865567              대신감정
# 1546          744            임의        일괄    370245291              삼정감정
# 1722          101            임의        일반    288564318            현대기업감정
# 1747         1314            강제        일반    201335667              더존감정
# 1808         1609            임의        개별    600000000              이노감정
# 1912          102            임의        일반    357918375              대신감정
#
#            Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 29    2012-06-11 00:00:00              6                          5
# 32    2015-09-21 00:00:00              3                          1
# 81    2015-12-29 00:00:00              2                          1
# 84    2012-06-11 00:00:00              6                          5
# 118   2016-04-20 00:00:00              1                          0
# 122   2012-06-11 00:00:00              6                          5
# 224   2012-06-11 00:00:00              7                          5
# 227   2016-02-05 00:00:00              2                          0
# 239   2012-06-11 00:00:00              6                          5
# 294   2016-02-12 00:00:00              1                          0
# 303   2016-05-16 00:00:00              2                          1
# 311   2012-06-11 00:00:00              7                          6
# 370   2012-06-11 00:00:00              6                          5
# 464   2012-06-11 00:00:00              6                          5
# 491   2012-06-11 00:00:00              7                          6
# 496   2012-06-11 00:00:00              5                          3
# 519   2016-10-07 00:00:00              3                          1
# 560   2012-06-11 00:00:00              6                          5
# 613   2012-06-11 00:00:00              6                          5
# 626   2016-08-29 00:00:00              3                          2
# 637   2012-06-11 00:00:00              7                          6
# 656   2012-06-11 00:00:00              6                          5
# 658   2012-06-11 00:00:00              6                          5
# 731   2011-12-31 00:00:00              4                          3
# 777   2016-12-12 00:00:00              2                          1
# 779   2016-06-20 00:00:00              2                          1
# 823   2016-07-22 00:00:00              1                          0
# 844   2015-04-24 00:00:00              3                          2
# 853   2017-04-19 00:00:00              2                          1
# 866   2015-12-26 00:00:00              2                          1
# 917   2016-06-01 00:00:00              2                          1
# 1065  2015-12-03 00:00:00              1                          0
# 1212  2016-07-12 00:00:00              5                          3
# 1266  2015-08-20 00:00:00              1                          0
# 1316  2015-09-18 00:00:00              2                          1
# 32             낙찰         Private      부산     연제구       연산동     NaN        Y
# 81             낙찰         Private      부산     연제구       연산동     NaN        N
# 84             낙찰         Private      부산     동래구       낙민동     NaN        N
# 118            낙찰         Private      부산     연제구       연산동     NaN        Y
# 122            낙찰         Private      부산     동래구       낙민동     NaN        N
# 224            낙찰         Private      부산     동래구       낙민동     NaN        N
# 227            낙찰         Private      부산     수영구       남천동     NaN        N
# 239            낙찰         Private      부산     동래구       낙민동     NaN        N
# 294            낙찰         Private      부산     수영구       남천동     NaN        N
# 303            낙찰            동래농협      부산    해운대구        중동     NaN        N
# 311            낙찰         Private      부산     동래구       낙민동     NaN        N
# 370            낙찰         Private      부산     동래구       낙민동     NaN        N
# 464            낙찰         Private      부산     동래구       낙민동     NaN        N
# 491            낙찰         Private      부산     동래구       낙민동     NaN        N
# 496            낙찰         Private      부산     동래구       낙민동     NaN        N
# 519            낙찰        동부화재해상보험      부산     영도구     대교동1가     NaN        N
# 560            낙찰         Private      부산     동래구       낙민동     NaN        N
# 613            낙찰         Private      부산     동래구       낙민동     NaN        N
# 626            낙찰  에프케이엔1612유동화전문      부산     사하구       괴정동     NaN        N
# 637            낙찰         Private      부산     동래구       낙민동     NaN        N
# 656            낙찰         Private      부산     동래구       낙민동     NaN        N
# 658            낙찰         Private      부산     동래구       낙민동     NaN        N
# 731            낙찰         Private      서울     양천구       신월동     NaN        N
# 777            낙찰            우리은행      서울     동작구       사당동     NaN        N
# 779            낙찰          페퍼저축은행      서울    동대문구       장안동     NaN        N
# 823            낙찰          광등종합건설      서울     노원구       공릉동     NaN        N
# 844            낙찰         Private      서울     서초구       서초동     NaN        N
# 853            낙찰            하나은행      서울     성북구       돈암동     NaN        N
# 866            낙찰       현대라이프생명보험      서울    영등포구      여의도동     NaN        N
# 917            낙찰            국민은행      서울    영등포구      여의도동     NaN        N
# 1065           낙찰        기술신용보증기금      서울    서대문구       홍은동     NaN        Y
# 1212           낙찰         Private      서울     강북구        번동     NaN        N
# 1266           낙찰            하나은행      서울     양천구       신월동     NaN        N
# 1316           낙찰         Private      서울     성동구       옥수동     NaN        N
# 1438           낙찰         Private      서울     강동구       성내동     NaN        N
# 1486           낙찰         Private      서울    서대문구       연희동     NaN        N
# 1521           낙찰          엘빈종합건설      서울     관악구       남현동     NaN        N
# 1546           낙찰            우리은행      서울    서대문구       홍은동     NaN        N
# 1722           낙찰           와이더블유      서울     서초구       서초동     NaN        N
# 1747           낙찰          아림조명상사      서울     성북구       돈암동     NaN        N
# 1808           낙찰          광등종합건설      서울     노원구       공릉동     NaN        N
# 1912           낙찰            국민은행      서울     서초구       방배동     NaN        N
#
#       addr_bunji1  addr_bunji2                                      addr_etc  \
# 29          236.0          NaN                             ,237-2 삼주 8층 801호
# 32           20.0         55.0                                    국토 4층 402호
# 81          406.0         10.0                       연산동한솔솔파크 101동 11층 1102호
# 84          236.0          NaN                             ,237-2 삼주 7층 701호
# 118          20.0         55.0                                    국토 1층 108호
# 122         236.0          NaN                             ,237-2 삼주 6층 602호
# 224         236.0          NaN                           ,237-2 삼주 11층 1101호
# 32    35.176351  129.111235      55203000
# 81    35.187269  129.103845     277111500
# 84    35.201112  129.088687     135330000
# 118   35.176351  129.111235      60000000
# 122   35.201112  129.088687     137800000
# 224   35.201112  129.088687     135500000
# 227   35.145924  129.110288     173300000
# 239   35.201112  129.088687     135330000
# 294   35.145924  129.110288     220500000
# 303   35.162281  129.168620     549990000
# 311   35.201112  129.088687     136000000
# 370   35.201112  129.088687     133630000
# 464   35.201112  129.088687     123000000
# 491   35.201112  129.088687     138010000
# 496   35.201112  129.088687     117800000
# 519   35.094470  129.036481     331000000
# 560   35.201112  129.088687     145990000
# 613   35.201112  129.088687     137800000
# 626   35.106003  129.002455     182530000
# 637   35.201112  129.088687     136500000
# 656   35.201112  129.088687     128900000
# 658   35.201112  129.088687     142630000
# 731   37.533991  126.823710     187500000
# 777   37.489550  126.973772     687880000
# 779   37.567122  127.063013     300000000
# 823   37.626154  127.070337     214090000
# 844   37.494985  127.020908     864999999
# 853   37.597690  127.010683     407001000
# 866   37.520251  126.926386    1131110000
# 917   37.520239  126.931751    1023070000
# 1065  37.600584  126.946719     387489000
# 1212  37.637280  127.031419    3721000000
# 1266  37.533991  126.823710     255100000
# 1316  37.542245  127.018346     734777000
# 1438  37.531094  127.133775     445000000
# 1486  37.567624  126.932096     295480000
# 1521  37.473014  126.974663   15151000000
# 1546  37.598049  126.955948     783001000
# 1722  37.481379  127.011757    1074010000
# 1747  37.600927  127.012525     150900000
# 1808  37.626154  127.070337     201999990
# 1912  37.479785  126.995602     920500000

# %%
# Apartment Usage에 어떤 값들이 있는 지 확인
print(Raw_train['Apartment_usage'].unique())
# Out:
# ['주상복합' '아파트']

# %%
# 사용하지 않은 feature drop
Raw_train = Raw_train.drop(['Auction_key', 'Appraisal_company', 'Final_result', 'Creditor', 'addr_do',
                           'addr_si', 'addr_dong', 'addr_li', 'addr_san', 'addr_bunji1', 'addr_bunji2',
                           'addr_etc', 'Specific', 'road_name', 'road_bunji1', 'road_bunji2', 'Close_date'], axis = 1)

Raw_train
# Out:
#      Auction_class Bid_class  Claim_price       Appraisal_date  Auction_count  \
# 0               임의        개별   1766037301  2017-07-26 00:00:00              2
# 1               임의        일반    152946867  2016-09-12 00:00:00              2
# 2               임의        개별     11326510  2016-11-22 00:00:00              3
# 3               임의        일반    183581724  2016-12-13 00:00:00              2
# 4               강제        일반     45887671  2016-03-07 00:00:00              2
# ...            ...       ...          ...                  ...            ...
# 1928            강제        일반    280000000  2017-02-16 00:00:00              1
# 1929            임의        일반    200000000  2015-02-21 00:00:00              2
# 1930            임의        일반    354805459  2016-10-21 00:00:00              2
# 1931            강제        일반     80000000  2016-06-17 00:00:00              2
# 1932            임의        일반    180000000  2015-04-17 00:00:00              2
#
#       Auction_miscarriage_count  Total_land_gross_area  Total_land_real_area  \
# 0                             1                12592.0                 37.35
# 1                             1                42478.1                 18.76
# 2                             2               149683.1                 71.00
# 3                             1                24405.0                 32.98
# 4                             1                  774.0                 45.18
# ...                         ...                    ...                   ...
# 1928                          0                66419.3                 40.55
# 1929                          1                20433.8                 39.60
# 1930                          1                 7460.8                 19.03
# 1931                          1                16875.8                 42.20
# 1932                          1                32457.1                 45.68
#
#       Total_land_auction_area  Total_building_area  \
# 0                       37.35               181.77
# 1                       18.76               118.38
# 2                       71.00                49.94
# 3                       32.98                84.91
# 4                       45.18                84.96
# ...                       ...                  ...
# 1928                    40.55                84.87
# 1929                    39.60               114.81
# 1930                    19.03               133.98
# 1931                    42.20                84.94
# 1932                    45.68               102.92
#
#       Total_building_auction_area  Total_appraisal_price  Minimum_sales_price  \
# 0                          181.77              836000000            668800000
# 1                          118.38             1073000000            858400000
# 2                           49.94              119000000             76160000
# 3                           84.91              288400000            230720000
# 4                           84.96              170000000            136000000
# ...                           ...                    ...                  ...
# 1928                        84.87              401000000            401000000
# 1929                       114.81              454000000            363200000
# 1930                       133.98             1285000000           1028000000
# 1931                        84.94              407000000            325600000
# 1932                       102.92              750000000            600000000
#
#        First_auction_date   Final_auction_date Apartment_usage  \
# 0     2018-02-13 00:00:00  2018-03-20 00:00:00            주상복합
# 1     2016-12-29 00:00:00  2017-02-02 00:00:00             아파트
# 2     2017-07-28 00:00:00  2017-10-13 00:00:00             아파트
# 3     2017-07-20 00:00:00  2017-11-02 00:00:00             아파트
# 4     2016-07-06 00:00:00  2016-08-03 00:00:00             아파트
# ...                   ...                  ...             ...
# 1928  2017-06-19 00:00:00  2017-06-19 00:00:00             아파트
# 1929  2017-02-13 00:00:00  2017-03-13 00:00:00             아파트
# 1930  2017-12-21 00:00:00  2018-01-18 00:00:00            주상복합
# 1931  2016-10-10 00:00:00  2016-11-14 00:00:00             아파트
# 1932  2016-04-20 00:00:00  2016-05-25 00:00:00             아파트
#
#      Preserve_regist_date  Total_floor  Current_floor Share_auction_YorN  \
# 0     2009-07-14 00:00:00           45              5                  N
# 1     2011-12-16 00:00:00           70             51                  N
# 2     1992-07-31 00:00:00           15             14                  N
# 3     2001-07-13 00:00:00           20             11                  N
# 4     2001-11-27 00:00:00            7              7                  N
# ...                   ...          ...            ...                ...
# 1928  1992-08-29 00:00:00           21             15                  N
# 1929  2000-05-30 00:00:00           23             23                  N
# 1930  2011-12-13 00:00:00           32             19                  N
# 1931  2002-11-07 00:00:00           15             11                  N
# 1932  2013-11-18 00:00:00           22              7                  N
#
#      Close_result    point.y     point.x  Hammer_price
# 0              배당  35.162717  129.137048     760000000
# 1              배당  35.156633  129.145068     971889999
# 2              배당  35.184601  128.996765      93399999
# 3              배당  35.154180  129.089081     256899000
# 4              배당  35.099630  128.998874     158660000
# ...           ...        ...         ...           ...
# 1928           배당  37.648811  127.048683     402500000
# 1929           배당  37.663291  127.077063     430234600
# 1930           배당  37.558319  126.981994    1118999990
# 1931           배당  37.647061  127.028002     403000000
# 1932           배당  37.566255  126.848961     686010000
#
# [1933 rows x 24 columns]

# %%
# feature engineering
from datetime import datetime, timedelta

def feature_engineering(df) :
    # 유찰 비율 feature 생성
    df['Miscarriage_rate'] = df['Auction_miscarriage_count'] / df['Auction_count']
    df = df.drop(['Auction_miscarriage_count', 'Auction_count'], axis = 1)
    
    # 층고율 feature 생성
    df['floor_rate'] = df['Current_floor'] / df['Total_floor']
    df = df.drop(['Current_floor', 'Total_floor'], axis = 1)
    
    # 감정가에 대한 최저매각가격의 부담율
    df['Minimum_per_appraisal'] = df['Minimum_sales_price'] / df['Total_appraisal_price']
    df = df.drop(['Minimum_sales_price'], axis = 1)
    
    # 감정가에 대한 청구금액의 부담율(비취하율)
    df['Claim_per_appraisal'] = df['Claim_price'] / df['Total_appraisal_price']
    df = df.drop(['Claim_price', 'Total_appraisal_price'], axis = 1)
    
    # 실질 경매 면적율
    df['Auction_real_area_rate'] = (((df['Total_land_real_area'] / df['Total_land_gross_area']) * df['Total_land_auction_area']) 
                                    + (df['Total_building_auction_area'] / df['Total_building_area']))
    df = df.drop(['Total_land_real_area', 'Total_land_gross_area', 'Total_land_auction_area',
                 'Total_building_auction_area', 'Total_building_area'], axis = 1)
    
    # One-hot Encoding
    df = pd.get_dummies(df, columns=['Auction_class', 'Auction_class', 'Apartment_usage', 'Share_auction_YorN', 'Close_result'])
    
    # date processing
    df['Appraisal_date'] = pd.to_datetime(Raw_train['Appraisal_date'], format="%Y-%m-%d %H:%M:%S")
    df['First_auction_date'] = pd.to_datetime(Raw_train['First_auction_date'], format="%Y-%m-%d %H:%M:%S")
    df['Final_auction_date'] = pd.to_datetime(Raw_train['Final_auction_date'], format="%Y-%m-%d %H:%M:%S")
    df['Preserve_regist_date'] = pd.to_datetime(Raw_train['Preserve_regist_date'], format="%Y-%m-%d %H:%M:%S")
    
    df['Preserve_to_Appraisal'] = df['Appraisal_date'] - df['Preserve_regist_date']
    df['Appraisal_to_first'] = df['First_auction_date'] - df['Appraisal_date']
    df['First_to_final'] = df['Final_auction_date'] - df['First_auction_date']
    
    df = df.drop(['Appraisal_date', 'First_auction_date', 'Final_auction_date', 'Preserve_regist_date'], axis = 1)
    
    return df

# %%
Raw_train = feature_engineering(Raw_train)

Raw_train
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-167-60463bf2eab4> in <module>
# ----> 1 Raw_train = feature_engineering(Raw_train)
#       2
#       3 Raw_train
#
# <ipython-input-166-cf400bb9cbbb> in feature_engineering(df)
#      32     df['First_auction_date'] = pd.to_datetime(Raw_train['First_auction_date'], format="%Y-%m-%d %H:%M:%S")
#      33     df['Final_auction_date'] = pd.to_datetime(Raw_train['Final_auction_date'], format="%Y-%m-%d %H:%M:%S")
# ---> 34     df['Preserve_regist_date'] = pd.to_datetime(Raw_train['Preserve_regist_date'], format="%Y-%m-%d %H:%M:%S")
#      35
#      36     df['Preserve_to_Appraisal'] = df['Appraisal_date'] - df['Preserve_regist_date']
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     803             result = arg.map(cache_array)
#     804         else:
# --> 805             values = convert_listlike(arg._values, format)
#     806             result = arg._constructor(values, index=arg.index, name=arg.name)
#     807     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     463         assert format is None or infer_datetime_format
#     464         utc = tz == "utc"
# --> 465         result, tz_parsed = objects_to_datetime64ns(
#     466             arg,
#     467             dayfirst=dayfirst,
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2088             return values.view("i8"), tz_parsed
#    2089         except (ValueError, TypeError):
# -> 2090             raise e
#    2091
#    2092     if tz_parsed is not None:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2073
#    2074     try:
# -> 2075         result, tz_parsed = tslib.array_to_datetime(
#    2076             data,
#    2077             errors=errors,
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1111-11-11 00:00:00
